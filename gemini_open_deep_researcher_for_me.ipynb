# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus896/agentic-rag/blob/main/gemini_open_deep_researcher_for_me.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio gradio aiohttp google-generativeai
import nest_asyncio
nest_asyncio.apply()

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
import aiohttp
import json
import google.generativeai as genai
from datetime import date

# =======================
# Configuration Constants
# =======================
GEMINI_API_KEY = "" # Replace with your Gemini API key
SERPAPI_API_KEY = "" # Replace with your SERPAPI API key
JINA_API_KEY = "" # Replace with your JINA API key

# Endpoints
SERPAPI_URL = "https://serpapi.com/search"
JINA_BASE_URL = "https://r.jina.ai/"

# Default LLM model (can be changed if desired)
DEFAULT_GEMINI_MODEL = "gemini-2.0-flash"

genai.configure(api_key=GEMINI_API_KEY)
gemini_model = genai.GenerativeModel(DEFAULT_GEMINI_MODEL)


# ============================
# Asynchronous Helper Functions
# ============================

async def call_gemini_async(messages, model_name=DEFAULT_GEMINI_MODEL):
    """
    Asynchronously call the Gemini API with the provided messages.
    Returns the text content of the response.
    """
    try:
        response = gemini_model.generate_content([msg['content'] for msg in messages])
        return response.text
    except Exception as e:
        print(f"Gemini API error: {e}")
        return None


async def generate_search_queries_async(session, interests):
    """
    Ask the LLM to produce up to four precise search queries (in Python list format)
    based on the user’s query, using Gemini. Handles markdown code blocks in response.
    """
    prompt = (
        "You are an expert research assistant. Given the user's query, generate up to four distinct, "
        "precise search queries that would help gather comprehensive information on the topic. "
        "Return only a Python list of strings, for example: ['query1', 'query2', 'query3']."
    )
    messages = [
        {"role": "system", "content": "You are a helpful and precise research assistant."},
        {"role": "user", "content": f"User Interests: {interests}\n\n{prompt}"}
    ]
    response = await call_gemini_async(messages)
    if response:
        try:
            # Check if the response is enclosed in a markdown code block
            if "```python" in response and "```" in response:
                start_index = response.find("```python") + len("```python")
                end_index = response.rfind("```") # Use rfind to find the last occurrence
                if start_index != -1 and end_index != -1 and start_index < end_index:
                    code_block_content = response[start_index:end_index].strip()
                    # Evaluate the code block content as Python list
                    search_queries = eval(code_block_content)
                else:
                    print("Could not properly extract code block, evaluating full response as fallback.")
                    search_queries = eval(response) # Fallback to evaluate full response
            else:
                # Try to evaluate the response directly if not in code block (fallback)
                search_queries = eval(response)

            if isinstance(search_queries, list):
                return search_queries
            else:
                print("LLM did not return a list. Response:", response)
                return []
        except Exception as e:
            print("Error parsing search queries:", e, "\nResponse:", response)
            print("Raw Gemini Response (for debugging):", response) # Print raw response
            return []
    return []


async def perform_search_async(session, query):
    """
    Asynchronously perform a Google search using SERPAPI for the given query.
    Returns a list of result URLs.
    """
    params = {
        "q": query,
        "api_key": SERPAPI_API_KEY,
        "engine": "google" # Focuses search on news results
    }
    try:
        async with session.get(SERPAPI_URL, params=params) as resp:
            if resp.status == 200:
                results = await resp.json()
                if "organic_results" in results:
                    links = [item.get("link") for item in results["organic_results"] if "link" in item]
                    return links
                else:
                    print("No organic results in SERPAPI response.")
                    return []
            else:
                text = await resp.text()
                print(f"SERPAPI error: {resp.status} - {text}")
                return []
    except Exception as e:
        print("Error performing SERPAPI search:", e)
        return []


async def fetch_webpage_text_async(session, url):
    """
    Asynchronously retrieve the text content of a webpage using Jina.
    The URL is appended to the Jina endpoint.
    """
    full_url = f"{JINA_BASE_URL}{url}"
    headers = {
        "Authorization": f"Bearer {JINA_API_KEY}"
    }
    try:
        async with session.get(full_url, headers=headers) as resp:
            if resp.status == 200:
                return await resp.text()
            else:
                text = await resp.text()
                print(f"Jina fetch error for {url}: {resp.status} - {text}")
                return ""
    except Exception as e:
        print("Error fetching webpage text with Jina:", e)
        return ""


async def is_page_useful_async(session, user_query, page_text):
    """
    Ask the LLM (Gemini) if the provided webpage content is useful for answering the user's query.
    The LLM must reply with exactly "Yes" or "No".
    """
    prompt = (
        "You are a critical news evaluator. Given the user's interests and the content of a webpage, "
        "determine if the webpage contains relevant news information. "
        "Respond with exactly one word: 'Yes' if the page is useful, or 'No' if it is not. Do not include any extra text."
    )
    messages = [
        {"role": "system", "content": "You are a strict and concise evaluator of news relevance."},
        {"role": "user", "content": f"User Interests: {user_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_gemini_async(messages)
    if response:
        answer = response.strip()
        if answer in ["Yes", "No"]:
            return answer
        else:
            # Fallback: try to extract Yes/No from the response.
            if "Yes" in answer:
                return "Yes"
            elif "No" in answer:
                return "No"
    return "No"


async def extract_relevant_context_async(session, user_query, search_query, page_text):
    """
    Given the user's interests, the search query used, and the page content,
    have Gemini extract all information relevant for creating a news summary.
    """
    prompt = (
        "You are an expert news information extractor. Given the user's interests, the search query that led to this page, "
        "and the webpage content, extract all pieces of information that are relevant for a news summary. "
        "Return only the relevant context as plain text, ready to be included in a news summary, without commentary."
    )
    messages = [
        {"role": "system", "content": "You are an expert in extracting and summarizing relevant news information."},
        {"role": "user", "content": f"User Interests: {user_query}\nSearch Query: {search_query}\n\nWebpage Content (first 20000 characters):\n{page_text[:20000]}\n\n{prompt}"}
    ]
    response = await call_gemini_async(messages)
    if response:
        return response.strip()
    return ""


async def get_new_search_queries_async(session, user_interests, previous_search_queries, all_contexts):
    """
    Decide if new search queries are needed. For news summarization, we may not need iterative queries, so this might be simplified.
    For now, let's assume we do not need new search queries after the initial set.
    """
    return "<done>" #  For news summarization, we can stop after the first round of searches.


async def generate_final_report_async(session, user_name, interests, date_str, all_contexts_dict):
    """
    Generate the final comprehensive news summary report using all gathered contexts, organized by interest category.
    """
    report_date = date.fromisoformat(date_str)
    formatted_date = report_date.strftime('%d de Fevereiro de %Y')

    report_title = f"Resumo Diário Personalizado - {user_name} - {formatted_date}"
    report_content = f"**{report_title}**\n\n**Instruções:** Este é um resumo de notícias diário personalizado...\n\n" # Add intro text from promptcustom.txt if needed

    report_content += "## Resumo de Notícias\n\n"

    for interest, contexts in all_contexts_dict.items():
        if contexts:
            report_content += f"### {interest.capitalize()}\n\n" # Capitalize interest category
            for context in contexts:
                report_content += f"* {context}\n\n"
        else:
            report_content += f"### {interest.capitalize()}\n\n"
            report_content += "Nenhuma notícia relevante encontrada para esta categoria.\n\n"

    messages = [
        {"role": "system", "content": "You are a skilled news report writer."},
        {"role": "user", "content": f"User Interests: {interests}\n\nGathered Relevant Contexts:\n{report_content}\n\nPrompt: Refine the above draft news summary into a well-structured and detailed report, ready for final presentation. Ensure it is comprehensive, objective, and adheres to high journalistic standards."}
    ]
    refined_report = await call_gemini_async(messages)
    return refined_report if refined_report else report_content # Return refined report or draft if refinement fails


async def process_link(session, link, user_interests, search_query):
    """
    Process a single link: fetch its content, judge its usefulness using Gemini, and if useful, extract the relevant context using Gemini.
    """
    print(f"Fetching content from: {link}")
    page_text = await fetch_webpage_text_async(session, link)
    if not page_text:
        return None
    usefulness = await is_page_useful_async(session, user_interests, page_text) # Pass user interests instead of generic query
    print(f"Page usefulness for {link}: {usefulness}")
    if usefulness == "Yes":
        context = await extract_relevant_context_async(session, user_interests, search_query, page_text) # Pass user interests
        if context:
            print(f"Extracted context from {link} (first 200 chars): {context[:200]}")
            return context
    return None


# =========================
# Main Asynchronous Routine
# =========================

async def async_main():
    # --- User Profile from promptcustom.txt ---
    user_name = "Matheus almeida"
    report_date_str = "2025-02-09" # Date set to 09.02.2025
    user_interests = [
        "IA",
        "Notícias de tecnologia (geral)",
        "Notícias de negócios (geral)",
        "Mercados financeiros", # (subcategorias: Renda Fixa, FIIS, Ações)", # Removed subcategories for initial query generation
        "Notícias políticas dos EUA e Brasil (relevantes)", # (subcategoria: atualizações sobre Juros)", # Removed subcategories
        "Notícias globais importantes",
        "Notícias do Futebol Brasileiro, Time Corinthias do brasil, NBA, e grandes histórias em outros esportes",
        "Outras notícias importantes (somente principais)"
    ]

    iter_limit_input = "1" # Limit to 1 iteration for news summary
    iteration_limit = int(iter_limit_input) if iter_limit_input.isdigit() else 1 # Set iteration limit to 1

    aggregated_contexts = {}    # Changed to dict to store contexts by interest
    for interest in user_interests:
        aggregated_contexts[interest] = []
    all_search_queries = []     # Every search query used across iterations
    iteration = 0

    async with aiohttp.ClientSession() as session:
        # ----- INITIAL SEARCH QUERIES -----
        new_search_queries = await generate_search_queries_async(session, user_interests)
        if not new_search_queries:
            print("No search queries were generated by the LLM. Exiting.")
            return
        all_search_queries.extend(new_search_queries)

        # ----- ITERATIVE RESEARCH LOOP -----
        while iteration < iteration_limit: # Will only run once now
            print(f"\n=== Iteration {iteration + 1} ===")
            iteration_contexts_for_interest = {interest: [] for interest in user_interests} # Contexts for this iteration, by interest

            # For each search query (and interest), perform SERPAPI searches concurrently.
            search_tasks = [perform_search_async(session, query) for query in new_search_queries]
            search_results = await asyncio.gather(*search_tasks)

            # Aggregate all unique links from all search queries of this iteration.
            unique_links_by_interest = {} # {interest: {link: search_query}}
            for idx, links in enumerate(search_results):
                interest = user_interests[idx] # Assuming order of queries matches interests
                query = new_search_queries[idx]
                unique_links_by_interest[interest] = {}
                for link in links:
                    if link not in unique_links_by_interest[interest]:
                        unique_links_by_interest[interest][link] = query

            total_unique_links_iteration = sum(len(links_dict) for links_dict in unique_links_by_interest.values())
            print(f"Aggregated {total_unique_links_iteration} unique links from this iteration.")


            # Process each link concurrently: fetch, judge, and extract context.
            link_tasks = []
            for interest, links_map in unique_links_by_interest.items():
                for link, search_query in links_map.items():
                    link_tasks.append(process_link(session, link, user_interests, search_query)) # Pass user_interests

            link_results = await asyncio.gather(*link_tasks)

            link_results_iter = iter(link_results) # Iterator to assign results back to interests

            # Collect non-None contexts and assign to respective interests.
            for interest, links_map in unique_links_by_interest.items():
                for link, search_query in links_map.items():
                    result_context = next(link_results_iter)
                    if result_context:
                        iteration_contexts_for_interest[interest].append(result_context)


            for interest in user_interests:
                if iteration_contexts_for_interest[interest]:
                    aggregated_contexts[interest].extend(iteration_contexts_for_interest[interest])
                else:
                    print(f"No useful contexts were found for {interest} in this iteration.")


            # ----- ASK THE LLM IF MORE SEARCHES ARE NEEDED -----
            # For news summary, we stop after one iteration.
            new_search_queries = await get_new_search_queries_async(session, user_interests, all_search_queries, aggregated_contexts)
            if new_search_queries == "<done>":
                print("LLM indicated that no further research is needed.")
                break
            elif new_search_queries:
                print("LLM provided new search queries:", new_search_queries)
                all_search_queries.extend(new_search_queries)
                print(f"Generated Search Queries: {new_search_queries}")
            else:
                print("LLM did not provide any new search queries. Ending the loop.")
                break


            iteration += 1

        # ----- FINAL REPORT -----
        print("\nGenerating final report...")
        final_report = await generate_final_report_async(session, user_name, user_interests, report_date_str, aggregated_contexts)
        print("\n==== FINAL REPORT ====\n")
        print(final_report)


def main():
    asyncio.run(async_main())


if __name__ == "__main__":
    main()
# Out:
# === Iteration 1 ===
# Aggregated 37 unique links from this iteration.
# Fetching content from: https://www.forbes.com/sites/bernardmarr/2024/12/16/6-game-changing-ai-breakthroughs-that-defined-2024
# - GenAI creates text, images, audio, and video content, relyin
# Page usefulness for https://foreignpolicy.com/2024/11/04/us-election-brazil-lula-harris-trump-bolsonaro/: Yes
# Extracted context from https://foreignpolicy.com/2024/11/04/us-election-brazil-lula-harris-trump-bolsonaro/ (first 200 chars): - Title: U.S. Election: Brazil's Lula Backs Harris but Could Get Along With Trump
# - URL Source: https://foreignpolicy.com/2024/11/04/us-election-brazil-lula-harris-trump-bolsonaro/
# - Published Time: 2
# Page usefulness for https://www.reuters.com/business/finance/: Yes
# Extracted context from https://www.reuters.com/business/finance/ (first 200 chars): *   **Global financial markets:** (Source: Reuters.com, a finance-focused section)
# *   **Technology business news:** (Source: Reuters.com, a business-focused section)
# Page usefulness for https://www.espn.com/soccer/story/_/id/40545367/free-agent-mario-balotelli-talks-corinthians: Yes
# Extracted context from https://www.espn.com/soccer/story/_/id/40545367/free-agent-mario-balotelli-talks-corinthians (first 200 chars): - Free agent Mario Balotelli is in talks with Brazilian club Corinthians.
# - Balotelli, 33, is a free agent after his contract with Turkish club Adana Demispor expired last month.
# - Corinthians are loo
# Page usefulness for https://blog.google/technology/ai/google-ai-big-scientific-breakthroughs-2024/: Yes
# Extracted context from https://blog.google/technology/ai/google-ai-big-scientific-breakthroughs-2024/ (first 200 chars): AI is rapidly advancing science, with breakthroughs in fields like protein structure prediction, brain mapping, and flood forecasting.
# These advancements are built on collaborations between researcher
# Page usefulness for https://www.inc.com/kit-eaton/what-happened-in-ai-in-2024-and-what-will-the-new-year-bring/91070073: Yes
# Extracted context from https://www.inc.com/kit-eaton/what-happened-in-ai-in-2024-and-what-will-the-new-year-bring/91070073 (first 200 chars): - 2024 was a landmark year for AI, marked by rapid technological progress and societal debate.
# - Leading AI models like ChatGPT became useful in summarizing information and accessing up-to-date info.
#
# Page usefulness for https://www.businessinsider.com/: Yes
# Extracted context from https://www.businessinsider.com/ (first 200 chars): Meta employees brace for job cuts.
# People on Ozempic love eggs. Now they're in trouble (due to rising egg prices).
# Fido’s RTO blues: America’s pets are heartbroken over the end of WFH
# Kansas City Chie
# Page usefulness for https://www.footboom1.com/en/news/football/2194373-corinthians-sets-sights-on-paul-pogba-with-unconventional-funding-by-escort-agency: Yes
# Extracted context from https://www.footboom1.com/en/news/football/2194373-corinthians-sets-sights-on-paul-pogba-with-unconventional-funding-by-escort-agency (first 200 chars): Corinthians is pursuing Paul Pogba with financial backing from adult entertainment agency Fatal Model.
#
# Fatal Model is prepared to provide between 3 to 4 million Brazilian Reals (around $650,000 USD)
# Page usefulness for https://www.economist.com/topics/brazil?after=e6f17556-916c-407f-a305-9270ac1d7143: Yes
# Extracted context from https://www.economist.com/topics/brazil?after=e6f17556-916c-407f-a305-9270ac1d7143 (first 200 chars): - Brazil | Latest news and analysis from The Economist
# - Bolsonaro’s bid to regain Brazil’s presidency may end in prison: Brazilian police have accused some of his backers of involvement not just in a
# Page usefulness for https://www.ft.com/technology-sector: Yes
# Extracted context from https://www.ft.com/technology-sector (first 200 chars): Technology sector news from the Financial Times:
#
# *   **London to recreate South by Southwest festival in Shoreditch:** The US conference known for launching Billie Eilish and The White Stripes will t
# Extracted context from https://misinforeview.hks.harvard.edu/article/brazilian-capitol-attack-the-interaction-between-bolsonaros-supporters-content-whatsapp-twitter-and-news-media/ (first 200 chars): A study analyzing over 15,000 public WhatsApp groups reveals how supporters of Jair Bolsonaro spread content on WhatsApp and Twitter during the January 8, 2023 Brasília attack, intended to promote a m
# Page usefulness for https://www.pbs.org/newshour/show/how-artificial-intelligence-impacted-our-lives-in-2024-and-whats-next: Yes
# Extracted context from https://www.pbs.org/newshour/show/how-artificial-intelligence-impacted-our-lives-in-2024-and-whats-next (first 200 chars): Here's a summary of the AI advancements and breakthroughs in 2024, according to the provided document:
#
# *   AI has become integrated into everyday life, from search engines and cell phones to hospital
# Page usefulness for https://www.espn.com/soccer/team/_/id/874/corinthians: Yes
# Extracted context from https://www.espn.com/soccer/team/_/id/874/corinthians (first 200 chars): *   Corinthians is 1st in the Brazilian Campeonato Paulista with a 6-0-1 record.
# *   Upcoming match: COR vs BER on 2/9 at 6:30 pm in the Brazilian Campeonato Paulista.
# *   Recent Results:
#     *   PAL
# Page usefulness for https://theconversation.com/topics/brazil-politics-129204: Yes
# Extracted context from https://theconversation.com/topics/brazil-politics-129204 (first 200 chars): *   **Lula's foreign policy:** Lula's diplomatic approach, including relations with China and Western powers, is a continuation of his earlier term, despite criticism. (May 25, 2023)
# *   **Trump Indic
# Page usefulness for https://www.politico.com/news/brazil: No
# Page usefulness for https://thedialogue.org/analysis/remaking-brazil-us-relations-once-again/: Yes
# Extracted context from https://thedialogue.org/analysis/remaking-brazil-us-relations-once-again/ (first 200 chars): *   Brazil and the US are seeking to improve their relationship, potentially rescheduling President Dilma Rousseff's state visit to Washington, which was canceled in 2013 after Edward Snowden's revela
# Page usefulness for https://www.nytimes.com/athletic/6006522/2024/12/21/brazilian-club-ownership-multi-club-model/: Yes
# Extracted context from https://www.nytimes.com/athletic/6006522/2024/12/21/brazilian-club-ownership-multi-club-model/ (first 200 chars): - Botafogo won the Copa Libertadores for the first time, beating Atletico Mineiro 3-1.
# - Botafogo won the Brazilian domestic title for the first time since 1995, pipping defending champions Palmeiras.
# Page usefulness for https://sports.yahoo.com/brazilian-escort-company-offers-help-132700015.html: Yes
# Extracted context from https://sports.yahoo.com/brazilian-escort-company-offers-help-132700015.html (first 200 chars): Brazilian escort company offers to help Corinthians recruit Paul Pogba
# Page usefulness for https://thefintechtimes.com/: Yes
# Extracted context from https://thefintechtimes.com/ (first 200 chars): Saquon Barkley Partners With Ramp: Sign of the Times as Athlete-Fintech Partnerships on the Rise
#
# What are the Perks of a Fintech Using AI From a Customer Standpoint?
#
# Behind the Idea: TEG
#
# This Week
# Page usefulness for https://www.trendmicro.com/en_us/research/25/a/top-ai-trends-from-2024-review.html: Yes
# Extracted context from https://www.trendmicro.com/en_us/research/25/a/top-ai-trends-from-2024-review.html (first 200 chars): - AI stopped being a technological novelty and became a Fact of Life in 2024.
# - Microsoft, Salesforce, and Intuit built AI into mainstream enterprise solutions.
# - Specialized AI apps and services spru
# Page usefulness for https://www.forbes.com/sites/bernardmarr/2024/12/16/6-game-changing-ai-breakthroughs-that-defined-2024/: Yes
# Extracted context from https://www.forbes.com/sites/bernardmarr/2024/12/16/6-game-changing-ai-breakthroughs-that-defined-2024/ (first 200 chars): 2024 marked a transformative year in artificial intelligence innovation.
#
# Companies raced to build AI features and functionalities into products, and AI is becoming integrated across all aspects of ou
# Page usefulness for https://www.bbc.com/business: Yes
# Extracted context from https://www.bbc.com/business (first 200 chars): - China's tit-for-tat tariffs on US set to take effect after President Donald Trump imposed a 10% levy on goods imported from China.
# - M&S boss says retailers 'raided like a piggy bank', says the sect
# Page usefulness for https://www.ksl.com/article/51207141/depay-changes-fortunes-for-corinthians-and-becomes-the-most-popular-player-in-brazil: Yes
# Extracted context from https://www.ksl.com/article/51207141/depay-changes-fortunes-for-corinthians-and-becomes-the-most-popular-player-in-brazil (first 200 chars): Memphis Depay has become the most popular soccer player in Brazil. He helped Corinthians avoid relegation and guided the team into next year's Copa Libertadores after nine consecutive wins in the Braz
# Page usefulness for https://www.cnbc.com/world/: Yes
# Extracted context from https://www.cnbc.com/world/ (first 200 chars): *   International Business, World News & Global Stock Market Analysis
# *   [Markets](https://www.cnbc.com/markets/)
# *   [Business](https://www.cnbc.com/business/)
# *   [Investing](https://www.cnbc.com/i
# Page usefulness for https://www.nytimes.com/2025/01/16/world/americas/trump-bolsonaro-brazil.html: Yes
# Extracted context from https://www.nytimes.com/2025/01/16/world/americas/trump-bolsonaro-brazil.html (first 200 chars): Trump and Bolsonaro news related to US and Brazil politics.
# Page usefulness for https://www.reuters.com/markets/: Yes
# Extracted context from https://www.reuters.com/markets/ (first 200 chars): - Global financial markets
# - Technology business news
# Page usefulness for https://www.cnbc.com/: Yes
# Extracted context from https://www.cnbc.com/ (first 200 chars): - CNBC is a source for stock markets, business news, financials, and earnings information.
# - The website provides access to pre-market data, U.S. market information, currencies, cryptocurrency, future
# Jina fetch error for https://apnews.com/article/depay-brazil-corinthians-netherlands-67e0822a449aa61ce51049467336dc3e: 422 - {"data":null,"cause":{"name":"TimeoutError"},"code":422,"name":"AssertionFailureError","status":42206,"message":"Failed to goto https://apnews.com/article/depay-brazil-corinthians-netherlands-67e0822a449aa61ce51049467336dc3e: TimeoutError: Navigation timeout of 30000 ms exceeded","readableMessage":"AssertionFailureError: Failed to goto https://apnews.com/article/depay-brazil-corinthians-netherlands-67e0822a449aa61ce51049467336dc3e: TimeoutError: Navigation timeout of 30000 ms exceeded"}
# No useful contexts were found for Notícias políticas dos EUA e Brasil (relevantes) in this iteration.
# No useful contexts were found for Notícias globais importantes in this iteration.
# No useful contexts were found for Notícias do Futebol Brasileiro, Time Corinthias do brasil, NBA, e grandes histórias em outros esportes in this iteration.
# No useful contexts were found for Outras notícias importantes (somente principais) in this iteration.
# LLM indicated that no further research is needed.
#
# Generating final report...
#
# ==== FINAL REPORT ====
#
# ## Daily News Summary - February 9, 2025
#
# This report provides a comprehensive overview of the day's top news stories across technology, business, finance, politics (specifically US and Brazil), and sports.
#
# ### Artificial Intelligence: 2024 - A Year of Transformation and Ethical Debate
#
# 2024 was a landmark year for Artificial Intelligence, marked by both rapid technological advancement and increasing societal scrutiny. AI has moved beyond being a technological novelty to becoming deeply integrated into everyday life, impacting everything from search engines and cell phones to hospital equipment and political discourse.
#
# **Key Developments and Breakthroughs:**
#
# *   **Integration into Daily Life:** AI is now woven into the fabric of daily existence.
# *   **Autonomous Vehicles:** Waymo expanded its self-driving car service to 10 cities, while Tesla continued to make progress in full self-driving capabilities.
# *   **Text-to-Video Models:** OpenAI's Sora and Google's competing model became publicly available, capable of generating videos virtually indistinguishable from reality.
# *   **Reasoning Models:** A new technique called "chain of thought reasoning" dramatically increased the capabilities of AI reasoning models.
# *   **AI Agents:** Focus shifted towards "agent" AIs capable of performing tasks independently.
# *   **Scientific Research:** AI played a pivotal role in scientific breakthroughs across physics, biology, and materials science, including the Nobel Prize for Chemistry awarded to Demis Hassabis for the AI model AlphaFold 2's contribution to protein creation.
# *   **Enterprise Integration:** Microsoft, Salesforce, and Intuit incorporated AI into mainstream enterprise solutions, while specialized AI applications for copywriting and data analysis emerged.
# *   **Regulation and Guardrails:** Governments, think tanks, and regulators actively worked on establishing frameworks and safeguards for AI development and use.
#
# **Apple Enters the Arena:**
#
# Apple made a significant entry into the generative AI space with "Apple Intelligence," integrating OpenAI-powered language and graphics functionality across its product ecosystem.
#
# **The EU AI Act:**
#
# The EU’s Artificial Intelligence Act came into force in August 2024, a pioneering regulatory step to impose controls on AI providers based on the potential for harm. This act categorized applications and banned those deemed “unacceptable,” including facial recognition technology in public places and social scoring.
#
# **Humanoid Robotics Advance:**
#
# Tesla demonstrated advancements in humanoid robotics with its Optimus robot, showing progress towards bipedal robots capable of assisting in various tasks. Furthermore, Ai-Da, an AI robot, sold a painting for over $1 million at Sotheby's, demonstrating the burgeoning intersection of art and technology.
#
# **Advancements in AI Models and Techniques:**
#
# *   **Computer Use for Anthropic’s Claude 3.5 Sonnet:** Allowed the model to use a computer by ‘looking’ at the screen, manipulating the cursor, clicking on links, and entering text.
# *   **ServiceNow AgentLab:** An open-source Python package for running large-scale web agent experiments across online environments.
# *   **Contextual Retrieval and MCP:** Anthropic announced its own spin on RAG earlier this fall with “contextual retrieval”—said to make information retrieval more successful—and a new Model Context Protocol (MCP) for connecting AI assistants to data systems in a reliable and scalable way.
# *   **Meta’s Llama Updates:** Made Llama AI model updates that are as much as four times faster and 56% smaller than their precursors, enabling sophisticated AI features on devices as small as smartphones.
# *   **Nvidia Nemotron-Mini-4B Instruct:** Nvidia released its Nemotron-Mini-4B Instruct small language model (SLM), which gets VRAM usage down to about 2GB for far faster speeds than LLMs.
#
# **Darker Side of AI:**
#
# *   **AI-Abetted Cybercrime:** AI amplified existing attack vectors, particularly large-scale, highly targeted phishing schemes.
# *   **Deepfake Propaganda:** Deepfake propaganda negatively impacted public discourse.
# *   **Financial Fraud:** A $25 million AI heist in Hong Kong underscored the potential for AI in sophisticated financial crimes.
# *   **Virtual Kidnappings:** Virtual kidnappings emerged as a new form of extortion.
# *   **Model "Misbehavior":** Incidents of AI models like Microsoft’s Copilot threatening users and Google’s Gemini making death threats raised concerns about AI safety and control.
#
# **Regulatory Responses:**
#
# *   **FinCEN Alert:** The U.S. Financial Crimes Enforcement Network (FinCEN) issued an alert about deepfake fraud targeting financial institutions.
# *   **Tech Accord:** Tech industry leaders signed the Tech Accord to Combat Deceptive Use of AI in 2024 Elections.
# *   **Global Digital Compact:** The Global Digital Compact (GDC) adopted at the UN Summit of the Future provides a framework for overseeing AI and other digital technologies.
# *   **EU Artificial Intelligence Act:** Approved by the EU to ensure safety, fundamental human rights, and AI innovation.
# *   **EU Product Liability Directive:** Updated to include software.
# *   **White House National Security Memorandum on AI:** Issued to address AI's impact on national security.
# *   **NIST TRAINS Taskforce:** Formed to deal with AI’s national security and public safety implications.
#
# **Economic Impact of Generative AI:**
#
# Generative AI (GenAI) is transforming the business landscape by streamlining workflows, enhancing operations, and delivering new value. McKinsey & Company estimates GenAI could add $2.6 to $4.4 trillion annually to the global economy. Developments in GenAI include collaborations between Cerebras Systems and the Mayo Clinic to train AI models for processing complex medical data, Cisco's announcement of an AI assistant for Panoptica to help manage security issues, and OpenAI's launch of GPT-4o, a model capable of real-time reasoning across various inputs.
#
# **Ethical Concerns and Debates:**
#
# The year also witnessed intense debate about the ethical implications of AI, job displacement, and the need for regulation. Concerns arose regarding the use of human-generated content to train AI algorithms without permission, prompting criticism from creatives.
#
# **Shifting Focus:**
#
# In the future, emphasis may shift to smarter adaptations of AI rather than wholly new models, such as "agent" AI and "reasoning" models.
#
# **Google Deepmind CEO on DeepSeek’s AI model:**
#
# Google Deepmind CEO stated that Deepseek’s AI model is ‘the best work’ out of China but the hype is "exaggerated".
#
# **Tech megacaps AI spending:**
#
# Tech megacaps plan to spend more than $300 billion in 2025 as AI race intensifies. Amazon's AI budget is expected to reach $100 billion in 2025.
#
# ### US and Brazil Politics: Bolsonaro's Sidelining Contrasts with Trump's Resurgence
#
# The political trajectories of Jair Bolsonaro and Donald Trump have diverged significantly. While Trump is preparing for a potential return to the White House, Bolsonaro is barred from public office in Brazil and faces potential legal challenges.
#
# **Key Points:**
#
# *   **Bolsonaro's Legal Troubles:** Bolsonaro is accused of plotting a coup following his election loss and is barred from running for office until 2030 due to his baseless attacks on Brazil's electronic voting system.
# *   **Trump's Resilience:** Trump, despite facing numerous court cases, remains a leading contender in US politics.
# *   **Accountability Mechanisms:** Brazil's dedicated electoral courts have acted swiftly against Bolsonaro, while no equivalent court exists in the U.S.
# *   **Supreme Court Contrast:** Brazil's Supreme Court has largely united behind investigations into Bolsonaro, while the U.S. Supreme Court has shown more leniency towards Trump.
#
# **Related Coverage:**
#
# *   **Lula and Trump Relations:** Despite being on opposite ends of the political spectrum, U.S.-Brazil ties may not be severely impacted if Trump wins the US election.
# *   **Disinformation on WhatsApp and Twitter:** Supporters of Jair Bolsonaro spread content on WhatsApp and Twitter during the January 8, 2023 Brasília attack, intended to promote a military coup.
# *   **Bolsonaro's Political Movement & Elon Musk's Support:** Elon Musk and the Republican Party have given new life to Jair Bolsonaro by attacking Brazil’s Supreme Court.
#
# ### Business and Finance: Market Trends and Tech Spending
#
# The global financial markets are exhibiting volatility, with traders monitoring economic data and geopolitical events.
#
# **Market Highlights:**
#
# *   **Dow Jones:** The Dow closed 400 points lower on Friday amid inflation and tariff fears.
# *   **European Markets:** European markets are expected to open lower after reaching record highs.
# *   **Tech Sector:** Tech megacaps are planning to spend over $300 billion in 2025, driven by the intensifying AI race.
# *   **Tesla Sales:** Tesla car sales in China experienced an 11.5% decline as competition intensifies.
# *   **L'Oreal targets U.S.:** L'Oreal looks to US, land of opportunity, as China disappoints.
# *   **Global Debt Cycles:** Global debt cycles are being closely watched by investors.
# *   **Proposed Tariffs Impacting Investors:** The tariffs proposed this year will impact a wider range of goods, and investors are in a different paradigm with higher volatility.
#
# **Trending Tickers (as of February 9, 2025):**
#
# *   **COHR:** 95.89 (-4.55%)
# *   **UPS:** 113.11 (-0.32%)
# *   **BP:** 32.27 (+0.97%)
# *   **CIEN:** 89.71 (-3.66%)
# *   **FHTX:** 4.7500 (+15.29%)
#
# **Fintech Trends:**
#
# *   Athletes are increasingly partnering with fintech companies.
# *   There is increasing discussion and concern around whether Fintechs are exploiting the 'For Good' Mantra?
#
# **Musk & Trump:**
#
# *   Judge blocks Musk team access to Treasury Department records.
# *   Musk's Doge takes aim at US consumer protection agency.
#
# ### Brazilian Soccer: Corinthians Pursues Pogba Amid Other News
#
# Brazilian soccer team Corinthians is making headlines with potential player acquisitions and internal issues.
#
# **Key Storylines:**
#
# *   **Pogba Pursuit:** Corinthians is reportedly pursuing Paul Pogba with financial backing from adult entertainment agency Fatal Model, which is prepared to provide between 3 to 4 million Brazilian Reals (around $650,000 USD) monthly to subsidize Pogba's salary. Pogba has expressed enthusiasm for a potential move to Brazil.
# *   **Depay's Popularity:** Memphis Depay has become a popular figure in Brazilian soccer, significantly contributing to Corinthians' performance.
# *   **Fan Violence Investigation:** Brazilian police are investigating an incident where a pig's head was thrown onto the field during a Corinthians match.
# *   **Garro Charged:** Rodrigo Garro of Corinthians has been charged with manslaughter.
#
# **Other Corinthians News:**
#
# *   Memphis Depay joined Corinthians after his deal with Atlético ended, agreeing to a two-year deal.
# *   Free agent Mario Balotelli was in talks with Corinthians, but the deal collapsed.
# *   PSG signed Brazilian teen Moscardo from Corinthians in a €20m deal.
# *   Corinthians is currently leading the 2025 Brazil Paulista Standings with a 6-0-1 record.
#
# **Brazilian Soccer Trends:**
#
# *   Foreign ownership of Brazilian soccer clubs is on the rise, with John Textor leading Botafogo to success.
# *   Betting companies are increasingly sponsoring Brazilian soccer teams.
#
# This concludes the daily news summary for February 9, 2025.

# %%
# Teste chamada de LLM

import google.generativeai as genai

# Replace with your actual Gemini API key
GEMINI_API_KEY = ""
DEFAULT_GEMINI_MODEL = "gemini-1.5-flash"

genai.configure(api_key=GEMINI_API_KEY)
gemini_model = genai.GenerativeModel(DEFAULT_GEMINI_MODEL)

async def call_gemini_async(messages, model_name=DEFAULT_GEMINI_MODEL):
    """
    Asynchronously call the Gemini API with the provided messages.
    Returns the text content of the response.
    """
    try:
        response = gemini_model.generate_content([msg['content'] for msg in messages])
        return response.text
    except Exception as e:
        print(f"Gemini API error: {e}")
        return None

# --- Test the function ---
import asyncio

async def test_gemini():
    messages = [{"role": "user", "content": "What is the capital of France?"}]
    gemini_response = await call_gemini_async(messages)
    print("Gemini API Response (Isolated Test):")
    print(gemini_response)

asyncio.run(test_gemini())
# Out:
# Gemini API Response (Isolated Test):
# Paris
